# %% [markdown]
# # Teorema de Bayes — Fábrica con 3 líneas (A, B, C)
#
# **Enunciado**
# En una fábrica de galletas hay tres líneas de producción: A, B y C.
# Cada línea produce una fracción distinta del total y tiene su tasa de defectos
#
# **Datos del problema:**
# - Producción por línea: A = 45%, B = 30%, C = 25%.
# - Porcentajes de defectos: P(D|A) = 3%, P(D|B) = 4%, P(D|C) = 5%.
#
# **Ejercicios:**
#
# a) Calcular la probabilidad total de defecto P(D).
#
# b) Dado que una bolsa es defectuosa, calcular P(B|D).
#
# c) ¿Qué línea tiene mayor probabilidad de haber producido la bolsa defectuosa? (Calcular P(A|D) y P(C|D) también).

# %%
# Parámetros
w_A, w_B, w_C = 0.45, 0.30, 0.25          # mezcla de producción
pD_A, pD_B, pD_C = 0.03, 0.04, 0.05       # tasas de defecto condicionales

# a) Probabilidad total de defecto (regla de la probabilidad total):


# b) Teorema de Bayes para la línea B:


# (c) También calculamos P(A|D) y P(C|D)

# %% [markdown]
# ### Resultados esperados (redondeados a 3 decimales)
# - **P(D) = 0.038**
# - **P(B|D) = 0.316**
# - **P(A|D) = 0.355**
# - **P(C|D) = 0.329**
#
# ---
# **Referencia:** [Teorema de Bayes — Academia Carta Blanca](https://academiacartablanca.es/blog/teorema-de-bayes-probabilidad/)

# %% [markdown]
# <sub>Notebook generado para clase — última actualización: 2025-11-04 08:42:16</sub>
